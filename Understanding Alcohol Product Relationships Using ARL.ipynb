# %% [markdown]
# # Project Overview
#
# Our client is looking to re-jig the alcohol section within their store. Customers are often complaining that they can’t find the products they want, and are also wanting recommendations about which other products to try. On top of this, their marketing team would like to start running “bundled” promotions as this has worked well in other areas of the store - but need guidance with selecting which products to put together.
#
# They have provided us a sample of 3,500 alcohol transactions - our task is fairly open - to see if we can find solutions or insights that might help the business address the aforementioned problems!

# %%
pip install apyori
# Out:
# Collecting apyori
#   Using cached apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=43b450bd86af8bb8b6d94fcac8ff62674a39e39dbaa6eb0aa1bbe4a1889f96d5
#   Stored in directory: /Users/praju/Library/Caches/pip/wheels/84/45/a4/8ade6576f75410d8162c6da1de0aa9df56c16c711acab5a813
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Associate Rules is an approach that is used to discover the strength of relationship between different
# data points

# it is more often used to find products that are frequently purchased together

import pandas as pd
import pickle
import matplotlib.pyplot as plt

from apyori import apriori

# %%
alcohol_transactions = pd.read_csv(r"/Users/praju/Desktop/DSI/Untitled Folder/ARL/sample_data_apriori.csv")

# %%
alcohol_transactions.head()
# Out:
#    transaction_id           product1         product2            product3  \
# 0               1      Premium Lager           Iberia                 NaN
# 1               2          Sparkling    Premium Lager       Premium Cider
# 2               3  Small Sizes White  Small Sizes Red      Sherry Spanish
# 3               4           White Uk   Sherry Spanish                Port
# 4               5      Premium Lager   Over-Ice Cider  French White South
#
#            product4            product5            product6     product7  \
# 0               NaN                 NaN                 NaN          NaN
# 1         Own Label         Italy White       Italian White  Italian Red
# 2  No/Low Alc Cider        Cooking Wine  Cocktails/Liqueurs  Bottled Ale
# 3     Italian White         Italian Red                 NaN          NaN
# 4       French Rose  Cocktails/Liqueurs         Bottled Ale          NaN
#
#      product8     product9  ... product36 product37 product38 product39  \
# 0         NaN          NaN  ...       NaN       NaN       NaN       NaN
# 1  French Red  Bottled Ale  ...       NaN       NaN       NaN       NaN
# 2         NaN          NaN  ...       NaN       NaN       NaN       NaN
# 3         NaN          NaN  ...       NaN       NaN       NaN       NaN
# 4         NaN          NaN  ...       NaN       NaN       NaN       NaN
#
#   product40 product41 product42 product43 product44 product45
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 46 columns]

# %%
alcohol_transactions.shape
# Out:
# (3567, 46)

# %%
alcohol_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3567 entries, 0 to 3566
# Data columns (total 46 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  3567 non-null   int64
#  1   product1        3567 non-null   object
#  2   product2        2988 non-null   object
#  3   product3        2550 non-null   object
#  4   product4        2189 non-null   object
#  5   product5        1875 non-null   object
#  6   product6        1642 non-null   object
#  7   product7        1425 non-null   object
#  8   product8        1229 non-null   object
#  9   product9        1078 non-null   object
#  10  product10       939 non-null    object
#  11  product11       810 non-null    object
#  12  product12       702 non-null    object
#  13  product13       610 non-null    object
#  14  product14       528 non-null    object
#  15  product15       446 non-null    object
#  16  product16       374 non-null    object
#  17  product17       330 non-null    object
#  18  product18       281 non-null    object
#  19  product19       238 non-null    object
#  20  product20       197 non-null    object
#  21  product21       167 non-null    object
#  22  product22       139 non-null    object
#  23  product23       119 non-null    object
#  24  product24       102 non-null    object
#  25  product25       87 non-null     object
#  26  product26       70 non-null     object
#  27  product27       54 non-null     object
#  28  product28       47 non-null     object
#  29  product29       37 non-null     object
#  30  product30       34 non-null     object
#  31  product31       25 non-null     object
#  32  product32       21 non-null     object
#  33  product33       19 non-null     object
#  34  product34       17 non-null     object
#  35  product35       13 non-null     object
#  36  product36       8 non-null      object
#  37  product37       7 non-null      object
#  38  product38       7 non-null      object
#  39  product39       7 non-null      object
#  40  product40       4 non-null      object
#  41  product41       3 non-null      object
#  42  product42       3 non-null      object
#  43  product43       3 non-null      object
#  44  product44       2 non-null      object
#  45  product45       2 non-null      object
# dtypes: int64(1), object(45)
# memory usage: 1.3+ MB

# %%
alcohol_transactions.drop('transaction_id',axis=1,inplace=True)

# %%
# apriori is slightly different from scikit learn.. here it won't
# accept data in form of dataframe or array
# it wants us to provide data as list of list
# each transaction we have will be one list and contains one element for each product in that
# transaction

# so for us all 3567 of these transaction list will contain one master list

transactions_list = []

for index,row in alcohol_transactions.iterrows():
    transactions = list(row.dropna())
    transactions_list.append(transactions)

# %%
transactions_list
# Out:
# [['Premium Lager', 'Iberia'],
#  ['Sparkling',
#   'Premium Lager',
#   'Premium Cider',
#   'Own Label',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French Red',
#   'Bottled Ale'],
#  ['Small Sizes White',
#   'Small Sizes Red',
#   'Sherry Spanish',
#   'No/Low Alc Cider',
#   'Cooking Wine',
#   'Cocktails/Liqueurs',
#   'Bottled Ale'],
#  ['White Uk', 'Sherry Spanish', 'Port', 'Italian White', 'Italian Red'],
#  ['Premium Lager',
#   'Over-Ice Cider',
#   'French White South',
#   'French Rose',
#   'Cocktails/Liqueurs',
#   'Bottled Ale'],
#  ['Kosher Red'],
#  ['Own Label', 'Italy White', 'Australian Red'],
#  ['Brandy/Cognac'],
#  ['Small Sizes White', 'Bottled Ale'],
#  ['White Uk',
#   'Spirits Mixers',
#   'Sparkling',
#   'German',
#   'Australian Red',
#   'American Red'],
#  ['World Beer',
#   'Sparkling',
#   'Premium Cider',
#   'Port',
#   'Iberia',
#   'Beer/Lager Gifts'],
#  ['Gin'],
#  ['Sparkling',
#   'South America White',
#   'South African White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italian Red',
#   'Iberia White',
#   'Iberia',
#   'French Red 2',
#   'Australian White'],
#  ['Standard Lager',
#   'South Africa Red',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French Red South',
#   'Everyday Cider',
#   'Australian Red',
#   'Australia White'],
#  ['Iberia'],
#  ['Vermouths/Aperitifs', 'Premium Cider', 'French Red 2'],
#  ['Sherry Spanish',
#   'Red Wine Bxes & 25Cl',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red'],
#  ['South America', 'Rum', 'French White 2', 'Champagne'],
#  ['Vodka', 'Basics'],
#  ['Stout',
#   'Small Sizes White',
#   'Premium Lager',
#   'New Zealand White',
#   'Lo/No Alcho Red Cgb',
#   'Italian Red',
#   'French Red',
#   'Bottled Ale'],
#  ['Spirits Mixers', 'Small Sizes White'],
#  ['Small Sizes White',
#   'Sherry Spanish',
#   'Iberia',
#   'Champagne',
#   'Brnd Alchol Carbntes'],
#  ['World Beer',
#   'South America White',
#   'South Africa Red',
#   'Premium Canned Ale',
#   'Over-Ice Cider',
#   'Iberia',
#   'Gin',
#   'Champagne',
#   'Brandy/Cognac'],
#  ['Vodka', 'Speciality Beer', 'Cocktails/Liqueurs'],
#  ['White Rum',
#   'Whisky',
#   'Vodka',
#   'Stout',
#   'Sparkling',
#   'Over-Ice Cider',
#   'Malt Whisky',
#   'Iberia White',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'American White',
#   'America White'],
#  ['French White'],
#  ['Sparkling',
#   'South America',
#   'South Africa Red',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French Red South',
#   'Cocktails/Liqueurs',
#   'Bitter',
#   'Australian Red'],
#  ['Everyday Cider', 'Australian White', 'Australian Red', 'American White'],
#  ['Speciality Beer',
#   'Sparkling',
#   'Premium Lager',
#   'Fruit Cider',
#   'Everyday Cider',
#   'Australian White',
#   'American Red',
#   'America White'],
#  ['White Boxes', 'Italian White', 'Australian White'],
#  ['Other Red', 'Fruit Cider', 'Cocktails/Liqueurs'],
#  ['Red Wine Bxes & 25Cl'],
#  ['White Rum',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian White',
#   'Gin',
#   'Brnd Alchol Carbntes',
#   'Bitter',
#   'American White',
#   'America White'],
#  ['South America White', 'South America', 'Australia White'],
#  ['Stout',
#   'Std Canned Ale',
#   'Standard Lager',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'Lo/No Alcho Red Cgb',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Bitter',
#   'Australian White',
#   'Australian Red',
#   'American Rose',
#   'American Red'],
#  ['World Beer', 'Premium Lager', 'Bottled Ale', 'Australian Red'],
#  ['Sherry Spanish'],
#  ['Brandy/Cognac'],
#  ['Speciality Beer',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'New Zealand White',
#   'French Red 2',
#   'Bottled Ale',
#   'Australian Red'],
#  ['Rum', 'Bottled Ale'],
#  ['White Boxes',
#   'Whisky',
#   'Standard Lager',
#   'Speciality Beer',
#   'Sparkling',
#   'Sherry Spanish',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Port',
#   'Made Wine British',
#   'Gin',
#   'American Red'],
#  ['Other Red', 'Iberia White', 'Champagne'],
#  ['Small Sizes White',
#   'Port',
#   'French White South',
#   'French White 2',
#   'French White',
#   'French Red South',
#   'French Red 2',
#   'French Red',
#   'Champagne',
#   'Brandy/Cognac'],
#  ['Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South Africa Red',
#   'Rum',
#   'Premium Lager',
#   'Other Red',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French Red 2',
#   'French Red',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red',
#   'American Red'],
#  ['Whisky', 'Cocktails/Liqueurs', 'Bitter'],
#  ['Speciality Beer',
#   'Sherry Spanish',
#   'Port',
#   'Iberia White',
#   'Cocktails/Liqueurs'],
#  ['No/Low Alc Cider'],
#  ['Sparkling',
#   'Premium Lager',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Bottled Ale'],
#  ['World Beer',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Small Sizes White',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'Italian White',
#   'Iberia White',
#   'French Red 2',
#   'Cooking Wine',
#   'Cocktails/Liqueurs',
#   'Brnd Alchol Carbntes',
#   'Bottled Ale',
#   'Basics',
#   'Australian Red',
#   'American Red'],
#  ['Vermouths/Aperitifs',
#   'Stout',
#   'Sparkling',
#   'Over-Ice Cider',
#   'Italy White',
#   'America White'],
#  ['Bottled Ale'],
#  ['Stout',
#   'Std Canned Ale',
#   'Standard Lager',
#   'Speciality Beer',
#   'Premium Lager',
#   'Port',
#   'Over-Ice Cider',
#   'Everyday Cider'],
#  ['Standard Lager',
#   'Spirits Mixers',
#   'Speciality Beer',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'Small Sizes White',
#   'Made Wine British',
#   'Iberia White',
#   'Cocktails/Liqueurs',
#   'American White',
#   'American Rose',
#   'America White'],
#  ['World Beer',
#   'Whisky',
#   'Spirits Mixers',
#   'Speciality Beer',
#   'Sparkling',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Sherry Spanish',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Australian Red',
#   'American Red'],
#  ['Premium Lager',
#   'New Zealand White',
#   'New Zealand Red',
#   'Nablab',
#   'Italy White',
#   'Iberia White',
#   'French White 2',
#   'Brnd Alchol Carbntes'],
#  ['Sparkling',
#   'Italy White',
#   'French White 2',
#   'French Red 2',
#   'French Red',
#   'Fine Wines',
#   'Champagne'],
#  ['Premium Lager', 'Cocktails/Liqueurs'],
#  ['South America White',
#   'South America',
#   'South African White',
#   'South Africa Red',
#   'Premium Lager',
#   'Premium Cider',
#   'Italian Red',
#   'Everyday Cider',
#   'Australian Red',
#   'American Red'],
#  ['Spirits Mixers',
#   'Sparkling',
#   'Small Sizes White',
#   'Premium Lager',
#   'New Zealand White',
#   'Iberia White',
#   'German',
#   'French White South',
#   'America White'],
#  ['World Beer',
#   'White Rum',
#   'Whisky',
#   'Vodka',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South Africa White',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Iberia',
#   'Gin',
#   'French White 2',
#   'Champagne'],
#  ['Over-Ice Cider', 'Fruit Cider'],
#  ['Standard Lager',
#   'Sparkling',
#   'Sherry Spanish',
#   'Premium Canned Ale',
#   'Port',
#   'Italy White',
#   'Italian Red',
#   'Cocktails/Liqueurs',
#   'Bitter',
#   'Australian Red'],
#  ['World Beer',
#   'South America',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'Own Label',
#   'Italy White',
#   'Australian White'],
#  ['Stout'],
#  ['Port', 'New Zealand White', 'Brandy/Cognac'],
#  ['Whisky', 'Premium Lager', 'Gin'],
#  ['World Beer', 'Cocktails/Liqueurs'],
#  ['Premium Lager'],
#  ['Sparkling',
#   'Small Sizes Red',
#   'Premium Lager',
#   'Italy White',
#   'Italian Red',
#   'French Red 2',
#   'Everyday Cider',
#   'Bottled Ale',
#   'Bitter',
#   'Australian Red',
#   'America White'],
#  ['Standard Lager',
#   'South African White',
#   'Italian White',
#   'French White South',
#   'French White',
#   'Everyday Cider',
#   'Brnd Alchol Carbntes',
#   'Australia White',
#   'America White'],
#  ['World Beer',
#   'Standard Lager',
#   'Speciality Beer',
#   'South America White',
#   'Premium Lager',
#   'New Zealand White',
#   'Nablab',
#   'Italy White',
#   'Bottled Ale',
#   'Australian Red',
#   'Australia White'],
#  ['Premium Lager'],
#  ['Standard Lager', 'Italian White', 'American White'],
#  ['Stout', 'Standard Lager', 'Other Red'],
#  ['White Boxes',
#   'Spirits & Fortified',
#   'Sparkling',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Australian Red',
#   'America White'],
#  ['World Beer', 'Italy White', 'Italian Red'],
#  ['Iberia'],
#  ['Standard Lager', 'Sherry Cyprus', 'Premium Lager', 'America White'],
#  ['World Beer',
#   'Speciality Beer',
#   'Rum',
#   'Premium Lager',
#   'Other Red',
#   'Cocktails/Liqueurs',
#   'Bottled Ale'],
#  ['Whisky', 'Standard Lager', 'Other Red'],
#  ['Sparkling',
#   'South America White',
#   'Rum',
#   'Premium Lager',
#   'Premium Cider',
#   'New Zealand White',
#   'Madeira & Marsala',
#   'Italy White',
#   'French White Loire',
#   'French White 2',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Bottled Ale'],
#  ['South America White',
#   'South African White',
#   'Other Red',
#   'Italian Red',
#   'Iberia White',
#   'French White South',
#   'French Red 2'],
#  ['French Red South', 'French Red'],
#  ['Sparkling', 'Brandy/Cognac'],
#  ['Speciality Beer',
#   'Premium Cider',
#   'Iberia White',
#   'Fruit Cider',
#   'Bottled Ale',
#   'Australian Red',
#   'American White',
#   'American Red',
#   'America White'],
#  ['Speciality Beer',
#   'Sparkling',
#   'South Africa White',
#   'South Africa Red',
#   'Italy White',
#   'Australian White',
#   'Australian Red'],
#  ['World Beer', 'Italy White', 'Champagne', 'Bottled Ale', 'American Red'],
#  ['Standard Lager',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White'],
#  ['South Africa Red',
#   'Sherry Spanish',
#   'Other Red',
#   'Iberia',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Australian Red'],
#  ['Red Wine Bxes & 25Cl',
#   'French Red South',
#   'Cocktails/Liqueurs',
#   'Australian Red',
#   'American Rose'],
#  ['America White'],
#  ['Whisky',
#   'Standard Lager',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Fine Wines',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac'],
#  ['Over-Ice Cider', 'Other Red'],
#  ['Standard Lager', 'South Africa White', 'Premium Lager', 'Bitter'],
#  ['Italian White', 'Bitter', 'America White'],
#  ['White Boxes',
#   'Vodka',
#   'Over-Ice Cider',
#   'Italy White',
#   'Iberia',
#   'Cocktails/Liqueurs',
#   'Australian White'],
#  ['Stout',
#   'Sparkling',
#   'South Africa Red',
#   'Port',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'French White 2',
#   'Brnd Alchol Carbntes',
#   'Australian Red',
#   'Australia White'],
#  ['South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Own Label',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French White 2',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red'],
#  ['South Africa Red', 'Premium Lager', 'America White'],
#  ['South America'],
#  ['Sparkling',
#   'Over-Ice Cider',
#   'Italy White',
#   'French White 2',
#   'French Red 2'],
#  ['Italian White', 'Gin'],
#  ['White Rum',
#   'Vodka',
#   'Rum',
#   'Premium Cider',
#   'New Zealand White',
#   'Gin',
#   'French White Loire',
#   'Cocktails/Liqueurs',
#   'Bottled Ale'],
#  ['Stout', 'Sparkling', 'Rum', 'Cocktails/Liqueurs'],
#  ['Stout', 'Standard Lager', 'Everyday Cider', 'Bitter', 'American Red'],
#  ['Vodka',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'Over-Ice Cider',
#   'Fruit Cider',
#   'Australian Red'],
#  ['Sparkling', 'Brnd Alchol Carbntes'],
#  ['Sparkling',
#   'Small Sizes Red',
#   'Over-Ice Cider',
#   'Italian White',
#   'Iberia White',
#   'Iberia',
#   'French White South',
#   'Brnd Alchol Carbntes'],
#  ['South America',
#   'Rum',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'Australian Red'],
#  ['Premium Lager',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'Fruit Cider',
#   'Brnd Alchol Carbntes',
#   'Bitter',
#   'Basics'],
#  ['Vodka',
#   'Standard Lager',
#   'South America',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Rum',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Port',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French Red South',
#   'French Red 2',
#   'Fine Wines',
#   'Cocktails/Liqueurs',
#   'Bitter',
#   'Australian White',
#   'Australian Red',
#   'American Red',
#   'America White'],
#  ['Speciality Beer', 'Sparkling', 'Over-Ice Cider', 'Bottled Ale'],
#  ['South Africa Red',
#   'Italian Red',
#   'Iberia',
#   'French Red South',
#   'American Red'],
#  ['Standard Lager', 'Spirits Mixers', 'French Red 2'],
#  ['Standard Lager',
#   'Sparkling',
#   'South Africa White',
#   'South Africa Red',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Red'],
#  ['Stout',
#   'Speciality Beer',
#   'Sparkling',
#   'Red Wine Bxes & 25Cl',
#   'Port',
#   'Gin',
#   'Everyday Cider'],
#  ['Vodka',
#   'Over-Ice Cider',
#   'Italy White',
#   'French White 2',
#   'Australia White'],
#  ['White Uk',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French White 2',
#   'French White',
#   'French Red South',
#   'Champagne',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red',
#   'American White',
#   'American Red'],
#  ['German'],
#  ['Vermouths/Aperitifs', 'New Zealand White', 'French White 2'],
#  ['Sherry Spanish', 'German', 'Cocktails/Liqueurs'],
#  ['Speciality Beer', 'Small Sizes Red', 'Champagne', 'Bottled Ale'],
#  ['Sparkling', 'Premium Lager', 'Italian Red', 'Iberia', 'French Red 2'],
#  ['Premium Lager', 'French White 2', 'Champagne'],
#  ['Speciality Beer',
#   'Sparkling',
#   'Premium Lager',
#   'Other Red',
#   'New Zealand White',
#   'Low Alcohol A.C',
#   'Gin',
#   'Fruit Cider',
#   'French White South',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian Rose',
#   'Australian Red'],
#  ['South America White',
#   'South Africa White',
#   'Premium Lager',
#   'Other Red',
#   'New Zealand White',
#   'Australian Rose',
#   'America White'],
#  ['Whisky',
#   'Stout',
#   'Premium Lager',
#   'Port',
#   'French Red 2',
#   'Australian White'],
#  ['Standard Lager',
#   'South Africa Red',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Sherry Spanish',
#   'Italy White',
#   'Australian Red'],
#  ['Sparkling', 'Champagne', 'Australian Red'],
#  ['World Beer',
#   'Whisky',
#   'Vodka',
#   'Speciality Beer',
#   'Sherry Spanish',
#   'Italy White',
#   'Italian White'],
#  ['Speciality Beer', 'Bottled Ale'],
#  ['Italy White', 'Italian Red', 'Cocktails/Liqueurs', 'Australia White'],
#  ['Standard Lager',
#   'Sparkling',
#   'South Africa Red',
#   'New Zealand White',
#   'Italy White',
#   'Australian Red',
#   'American Red'],
#  ['Speciality Beer',
#   'South African White',
#   'South Africa Red',
#   'No/Low Alc Cider',
#   'Nablab',
#   'Iberia',
#   'Champagne',
#   'Australian White',
#   'Australian Red'],
#  ['Premium Lager', 'Gin', 'Bottled Ale'],
#  ['Sparkling', 'Premium Lager', 'Italian White'],
#  ['World Beer',
#   'Sparkling',
#   'South America',
#   'Premium Canned Ale',
#   'New Zealand White',
#   'Italian Red',
#   'French White South',
#   'French White 2',
#   'French White',
#   'Bottled Ale',
#   'Bitter',
#   'Australian White'],
#  ['World Beer',
#   'South America',
#   'South Africa Red',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Fruit Cider',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian Red'],
#  ['World Beer', 'Premium Lager', 'Nablab', 'Gin', 'Brandy/Cognac'],
#  ['Vermouths/Aperitifs',
#   'Sparkling',
#   'South America',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'New Zealand Red',
#   'Italy White',
#   'Iberia',
#   'French White 2',
#   'America White'],
#  ['Cocktails/Liqueurs'],
#  ['South America White', 'South America'],
#  ['Stout'],
#  ['World Beer',
#   'Italian Red',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['Whisky',
#   'Vodka',
#   'Standard Lager',
#   'Sparkling',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Gin',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['South Africa Red',
#   'Small Sizes Red',
#   'Over-Ice Cider',
#   'Italian Red',
#   'French Red',
#   'Australian Red'],
#  ['World Beer',
#   'Rum',
#   'Nablab',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian Red',
#   'American Red'],
#  ['Cocktails/Liqueurs'],
#  ['World Beer',
#   'White Boxes',
#   'Whisky',
#   'Vodka',
#   'Stout',
#   'Std Canned Ale',
#   'Standard Lager',
#   'Sparkling',
#   'South America',
#   'South Africa White',
#   'Sherry Spanish',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'New Zealand White',
#   'New Zealand Red',
#   'Malt Whisky',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia White',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'French Red',
#   'Everyday Cider',
#   'Champagne',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Bitter',
#   'Beer/Lager Gifts',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['Stout', 'Premium Lager', 'Italy White', 'Gin'],
#  ['Stout',
#   'Standard Lager',
#   'Sparkling',
#   'Sherry Spanish',
#   'Port',
#   'New Zealand White',
#   'Malt Whisky',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['World Beer',
#   'Vermouths/Aperitifs',
#   'Premium Canned Ale',
#   'Other Red',
#   'New Zealand White',
#   'Italy White',
#   'Iberia White',
#   'Iberia',
#   'French White 2',
#   'French Red 2',
#   'Everyday Cider',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Rose'],
#  ['White Boxes'],
#  ['Premium Lager',
#   'New Zealand White',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'Bitter',
#   'Australian Red'],
#  ['World Beer',
#   'White Rum',
#   'Vodka',
#   'Stout',
#   'Sparkling',
#   'South Africa Red',
#   'Premium Lager',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'Port',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Gin',
#   'French White Loire',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Brandy/Cognac',
#   'Australian Red'],
#  ['Standard Lager',
#   'Premium Lager',
#   'Port',
#   'Over-Ice Cider',
#   'Nablab',
#   'Italy White',
#   'Italian Red',
#   'Everyday Cider',
#   'British Fortified'],
#  ['White Uk',
#   'White Boxes',
#   'Whisky',
#   'Standard Lager',
#   'South African White',
#   'Own Label',
#   'Italy White',
#   'Iberia White',
#   'Gin',
#   'French White South',
#   'French White 2',
#   'Basics',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Rose',
#   'American Red',
#   'America White'],
#  ['Whisky', 'Small Sizes Wht Othr', 'Brandy/Cognac'],
#  ['World Beer', 'Italian Red'],
#  ['World Beer',
#   'Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South Africa Red',
#   'Rum',
#   'Premium Lager',
#   'New Zealand White',
#   'New Zealand Red',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'American White',
#   'America White'],
#  ['South America White',
#   'South African White',
#   'Low Alcohol A.C',
#   'Champagne',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'America White'],
#  ['World Beer', 'South America', 'French White 2'],
#  ['Whisky',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Other Red',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Red',
#   'America White'],
#  ['Fruit Cider'],
#  ['Bottled Ale'],
#  ['World Beer',
#   'White Boxes',
#   'Sparkling',
#   'South America White',
#   'South African White',
#   'Other Red',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'Champagne',
#   'Australian White',
#   'Australia White',
#   'American White',
#   'America White'],
#  ['Spirits Mixers', 'Premium Lager', 'Cocktails/Liqueurs'],
#  ['World Beer',
#   'Sparkling',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Sherry Spanish',
#   'Over-Ice Cider',
#   'Italian White',
#   'French Red 2',
#   'Bitter'],
#  ['Standard Lager'],
#  ['World Beer',
#   'Vodka',
#   'South America',
#   'South Africa Red',
#   'Gin',
#   'American White',
#   'America White'],
#  ['Premium Cider'],
#  ['Small Sizes Wht Othr',
#   'Small Sizes White',
#   'Iberia White',
#   'Iberia',
#   'Bottled Ale',
#   'America White'],
#  ['Red Wine Bxes & 25Cl', 'Italian White', 'French Red'],
#  ['White Boxes',
#   'Sherry Spanish',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Cocktails/Liqueurs'],
#  ['Sherry Spanish', 'Champagne'],
#  ['World Beer',
#   'White Boxes',
#   'Whisky',
#   'Standard Lager',
#   'Speciality Beer',
#   'Sparkling',
#   'Small Sizes White',
#   'Premium Lager',
#   'Other Red',
#   'Italy White',
#   'Gin',
#   'Fruit Cider',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian White',
#   'American White',
#   'American Red'],
#  ['Bottled Ale'],
#  ['Vermouths/Aperitifs',
#   'South America White',
#   'South African White',
#   'South Africa White',
#   'Sherry Spanish',
#   'Malt Whisky',
#   'Madeira & Marsala',
#   'Iberia',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australia White',
#   'American Rose'],
#  ['Vermouths/Aperitifs',
#   'Standard Lager',
#   'South America White',
#   'Premium Lager',
#   'Other Red',
#   'Basics',
#   'Australian White'],
#  ['Stout', 'Premium Lager', 'Port', 'Iberia White'],
#  ['World Beer',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'South Africa Red',
#   'Small Sizes Red',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian White',
#   'French Red South',
#   'Champagne',
#   'Bottled Ale',
#   'American White',
#   'American Red'],
#  ['Standard Lager',
#   'Sparkling',
#   'South America White',
#   'Premium Lager',
#   'Italian Red',
#   'French White 2',
#   'French Red 2'],
#  ['Vodka',
#   'Premium Lager',
#   'Port',
#   'Iberia',
#   'German',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian Red'],
#  ['Standard Lager', 'South America', 'American Red'],
#  ['Fruit Cider'],
#  ['Sparkling', 'Other Red', 'New Zealand White'],
#  ['Sparkling', 'American White'],
#  ['World Beer',
#   'Stout',
#   'Sparkling',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Premium Cider',
#   'Port',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'German',
#   'French Red South',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Rose'],
#  ['Sherry Spanish',
#   'Italy White',
#   'Italian Red',
#   'French White 2',
#   'Australian White',
#   'Australian Red',
#   'America White'],
#  ['Standard Lager',
#   'Sparkling',
#   'Premium Canned Ale',
#   'Iberia White',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['South America', 'Italian Red', 'Cocktails/Liqueurs'],
#  ['Standard Lager',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Red',
#   'America White'],
#  ['Premium Lager'],
#  ['Made Wine British', 'Australian White'],
#  ['Speciality Beer',
#   'Sparkling',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Port',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French Red South',
#   'Bottled Ale',
#   'Australian White',
#   'Australia White',
#   'American Red'],
#  ['New Zealand White', 'French White'],
#  ['Spirits Mixers', 'Sparkling', 'Premium Lager', 'Over-Ice Cider'],
#  ['Sparkling', 'Premium Lager', 'Australian White'],
#  ['Premium Canned Ale',
#   'Port',
#   'Malt Whisky',
#   'Iberia White',
#   'French Red 2',
#   'Brandy/Cognac',
#   'Australian Red'],
#  ['Vodka',
#   'South America White',
#   'South Africa White',
#   'Premium Lager',
#   'New Zealand White',
#   'French White South',
#   'French White Loire',
#   'French White 2'],
#  ['Sparkling',
#   'South African White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Fruit Cider',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'America White'],
#  ['Italy White'],
#  ['Sparkling',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'American White',
#   'American Rose',
#   'American Red'],
#  ['Speciality Beer', 'South America White', 'Own Label'],
#  ['Rum', 'New Zealand White', 'Gin', 'French White 2', 'Cocktails/Liqueurs'],
#  ['World Beer',
#   'Vodka',
#   'Standard Lager',
#   'Sparkling',
#   'South America White',
#   'Small Sizes White',
#   'New Zealand White',
#   'Fruit Cider',
#   'French White 2',
#   'Australian White'],
#  ['South America White',
#   'French White South',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Red'],
#  ['Port',
#   'Malt Whisky',
#   'French White 2',
#   'Fine Wines',
#   'Champagne',
#   'Brandy/Cognac'],
#  ['Standard Lager', 'Sparkling'],
#  ['World Beer',
#   'Vodka',
#   'Stout',
#   'South America',
#   'South Africa White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Gin',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Red'],
#  ['World Beer',
#   'White Boxes',
#   'South Africa White',
#   'Sherry Spanish',
#   'Premium Lager',
#   'New Zealand White',
#   'Gin',
#   'Everyday Cider',
#   'Australian White',
#   'Australian Red',
#   'America White'],
#  ['Vermouths/Aperitifs', 'Sparkling'],
#  ['Vodka',
#   'Sparkling',
#   'Sherry Spanish',
#   'Rum',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Gin',
#   'Bottled Ale',
#   'Bitter'],
#  ['Kosher'],
#  ['World Beer',
#   'Whisky',
#   'Sparkling',
#   'Premium Lager',
#   'New Zealand White',
#   'New Zealand Red',
#   'Malt Whisky',
#   'Made Wine British',
#   'French White 2',
#   'French White',
#   'French Red South',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian White',
#   'Australian Red'],
#  ['Whisky', 'Spirits Mixers', 'Premium Canned Ale', 'Bottled Ale'],
#  ['Speciality Beer', 'Premium Lager', 'Fruit Cider'],
#  ['Italy White', 'Bitter'],
#  ['White Boxes',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South Africa White',
#   'South Africa Red',
#   'New Zealand White',
#   'Italy White',
#   'Fruit Cider',
#   'French White South',
#   'French White 2',
#   'French Red 2',
#   'Champagne',
#   'Australian Red'],
#  ['Premium Cider', 'Italy White', 'Australian Red'],
#  ['Whisky',
#   'Vodka',
#   'Sparkling',
#   'South America',
#   'South Africa Red',
#   'Italy White',
#   'Gin',
#   'French Red 2',
#   'Australian Red',
#   'American Red'],
#  ['Wine Gifts',
#   'Stout',
#   'Standard Lager',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Other Red',
#   'New Zealand White',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'Bitter',
#   'Australian White',
#   'Australian Red'],
#  ['Basics'],
#  ['South America White',
#   'South Africa White',
#   'Premium Lager',
#   'New Zealand White',
#   'New Zealand Red',
#   'Gin',
#   'Australian Red',
#   'Australia White',
#   'American Red'],
#  ['Premium Lager'],
#  ['Sparkling',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'American White',
#   'American Red',
#   'America White'],
#  ['Premium Lager', 'American White'],
#  ['World Beer',
#   'Sparkling',
#   'South America White',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Made Wine British',
#   'Italian White',
#   'Iberia',
#   'Cocktails/Liqueurs',
#   'Australian Red',
#   'American White',
#   'America White'],
#  ['World Beer',
#   'Standard Lager',
#   'Sparkling',
#   'South Africa Red',
#   'Premium Canned Ale',
#   'Nablab',
#   'Italy White',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian Sparkling',
#   'Australian Red'],
#  ['Sparkling',
#   'South America',
#   'South African White',
#   'South Africa Red',
#   'Small Sizes White',
#   'Premium Lager',
#   'New Zealand White',
#   'Italy White',
#   'Iberia',
#   'French Red 2',
#   'Cooking Wine',
#   'Champagne',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red',
#   'Australia White'],
#  ['Standard Lager',
#   'South America White',
#   'Small Sizes Red',
#   'Italy White',
#   'Iberia',
#   'French Red 2',
#   'Australian White'],
#  ['World Beer',
#   'Speciality Beer',
#   'Sparkling',
#   'Port',
#   'Other Red',
#   'Made Wine British',
#   'Italy White',
#   'Italian Red',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Red'],
#  ['Over-Ice Cider', 'Italian Red'],
#  ['World Beer',
#   'Speciality Beer',
#   'Premium Lager',
#   'Iberia',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['White Rum',
#   'Sparkling',
#   'South America',
#   'Sherry Spanish',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'French White',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Bottled Ale',
#   'Australian White'],
#  ['Premium Lager',
#   'Over-Ice Cider',
#   'Italy White',
#   'Australian White',
#   'Australian Red'],
#  ['Vodka',
#   'South African White',
#   'South Africa White',
#   'Rum',
#   'Premium Lager',
#   'New Zealand White',
#   'Australian White',
#   'Australia White'],
#  ['Stout', 'Australian Red'],
#  ['White Rum',
#   'Vodka',
#   'Spirits Mixers',
#   'Speciality Beer',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Brnd Alchol Carbntes'],
#  ['Premium Lager'],
#  ['Sparkling'],
#  ['Sparkling', 'Iberia', 'French Red 2', 'Australian White', 'Australian Red'],
#  ['World Beer',
#   'White Boxes',
#   'Sparkling',
#   'South America White',
#   'South Africa White',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Iberia',
#   'Fruit Cider',
#   'Champagne',
#   'Australia White'],
#  ['Sherry Spanish', 'Cocktails/Liqueurs'],
#  ['Red Wine Bxes & 25Cl', 'Iberia'],
#  ['White Uk',
#   'White Boxes',
#   'Whisky',
#   'Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Rum',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Rose',
#   'American Red',
#   'America White'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'Own Label',
#   'Nablab',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia White',
#   'Iberia',
#   'German',
#   'French Red South',
#   'American Red',
#   'America White'],
#  ['World Beer',
#   'White Uk',
#   'White Rum',
#   'Whisky',
#   'Vodka',
#   'Standard Lager',
#   'Speciality Beer',
#   'Sparkling',
#   'Premium Lager',
#   'Port',
#   'Own Label',
#   'Cocktails/Liqueurs',
#   'Brnd Alchol Carbntes',
#   'Brandy/Cognac'],
#  ['Premium Lager', 'New Zealand White', 'Cocktails/Liqueurs'],
#  ['White Boxes',
#   'Whisky',
#   'Stout',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'Italian White'],
#  ['Standard Lager',
#   'Premium Lager',
#   'Champagne',
#   'Australian Red',
#   'Australia White'],
#  ['Vodka',
#   'South America',
#   'New Zealand White',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac',
#   'Australian Red',
#   'American White',
#   'American Red'],
#  ['South America',
#   'Italian Red',
#   'Iberia',
#   'French White',
#   'French Red 2',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red'],
#  ['Standard Lager'],
#  ['South America',
#   'South Africa Red',
#   'Own Label',
#   'Italy White',
#   'Italian Red',
#   'German',
#   'French Red South',
#   'Australian Red',
#   'Australia White'],
#  ['South Africa White'],
#  ['Sparkling',
#   'South African White',
#   'Over-Ice Cider',
#   'Malt Whisky',
#   'Italy White',
#   'Italian White'],
#  ['World Beer', 'Premium Lager', 'Over-Ice Cider', 'French White'],
#  ['South Africa White',
#   'South Africa Red',
#   'French White',
#   'French Red South',
#   'Australian White'],
#  ['Standard Lager',
#   'South America White',
#   'South America',
#   'Nablab',
#   'Italian Red'],
#  ['Standard Lager', 'Premium Lager'],
#  ['Vodka',
#   'Standard Lager',
#   'Sparkling',
#   'South America',
#   'South Africa Red',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'Gin',
#   'Fruit Cider',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'French Red',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'American White',
#   'American Red'],
#  ['Cocktails/Liqueurs'],
#  ['White Boxes',
#   'Vodka',
#   'Speciality Beer',
#   'Sherry Spanish',
#   'Rum',
#   'German',
#   'French White 2',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Australian White'],
#  ['White Rum',
#   'White Boxes',
#   'Red Wine Bxes & 25Cl',
#   'Australian White',
#   'American Rose',
#   'American Red'],
#  ['World Beer',
#   'White Boxes',
#   'Sparkling',
#   'South America',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Premium Lager',
#   'Own Label',
#   'Iberia',
#   'Gin',
#   'French White 2',
#   'French Red South',
#   'Brandy/Cognac',
#   'Bottled Ale',
#   'Australian Red'],
#  ['World Beer', 'New Zealand White'],
#  ['Sparkling', 'Own Label', 'New Zealand White', 'Gin'],
#  ['Premium Lager',
#   'French Red South',
#   'French Red 2',
#   'French Red',
#   'Australian Red'],
#  ['Australian Sparkling', 'Australian Red'],
#  ['Spirits Mixers',
#   'Premium Lager',
#   'Made Wine British',
#   'Italy White',
#   'Everyday Cider',
#   'American Red'],
#  ['Sherry Spanish', 'Cocktails/Liqueurs', 'Bottled Ale'],
#  ['Own Label', 'Australian White'],
#  ['White Boxes',
#   'Whisky',
#   'Vodka',
#   'Vermouths/Aperitifs',
#   'Sparkling',
#   'Small Sizes White',
#   'Rum',
#   'Premium Lager',
#   'Nablab',
#   'Fruit Cider',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'American White',
#   'American Red',
#   'America White'],
#  ['White Uk',
#   'Sparkling',
#   'Ready To Drink',
#   'Premium Lager',
#   'Other Red',
#   'French Red 2'],
#  ['Vodka',
#   'South African White',
#   'Premix Fruit Spirits',
#   'Premium Lager',
#   'Premium Cider',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red'],
#  ['South Africa Red',
#   'Other Red',
#   'Italy White',
#   'French Red 2',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Rose',
#   'American Red',
#   'America White'],
#  ['World Beer',
#   'South America White',
#   'South African White',
#   'South Africa White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'French White South',
#   'French White Loire',
#   'Australian White',
#   'Australia White'],
#  ['World Beer',
#   'South America',
#   'South African White',
#   'South Africa Red',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian White',
#   'French Red',
#   'Australian Red',
#   'Australia White',
#   'American Red',
#   'America White'],
#  ['Sparkling',
#   'Premium Lager',
#   'New Zealand White',
#   'French Red 2',
#   'French Red',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['World Beer',
#   'White Boxes',
#   'Vodka',
#   'Sparkling',
#   'South America White',
#   'Sherry Spanish',
#   'French White 2',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['Iberia'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'South Africa Red',
#   'Premium Lager',
#   'Italian Red',
#   'Iberia',
#   'French White 2',
#   'French White',
#   'French Red',
#   'Australian Red'],
#  ['South America',
#   'Sherry Spanish',
#   'Italian Red',
#   'Iberia',
#   'Bottled Ale',
#   'Australian White'],
#  ['Standard Lager'],
#  ['Sparkling', 'Cooking Wine', 'Australian Red'],
#  ['Standard Lager',
#   'South America White',
#   'South African White',
#   'Premium Lager',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Iberia White',
#   'Iberia',
#   'Champagne',
#   'American Red'],
#  ['Australian Red'],
#  ['World Beer', 'Vodka'],
#  ['Fruit Cider', 'Cocktails/Liqueurs'],
#  ['Standard Lager',
#   'Sparkling',
#   'South America',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Italian Red',
#   'Iberia',
#   'Gin',
#   'Fruit Cider',
#   'Cocktails/Liqueurs',
#   'Beer/Lager Gifts',
#   'Australian Red'],
#  ['Iberia'],
#  ['White Boxes',
#   'South Africa Red',
#   'Own Label',
#   'French Red 2',
#   'Champagne',
#   'American White'],
#  ['South America White',
#   'South Africa Red',
#   'Premium Lager',
#   'French Red 2',
#   'Australia White'],
#  ['Italy White'],
#  ['Standard Lager', 'No/Low Alc Cider'],
#  ['World Beer',
#   'Sparkling',
#   'Sherry Spanish',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian White',
#   'French White South',
#   'French White Loire',
#   'French White 2',
#   'Champagne',
#   'Brandy/Cognac'],
#  ['Iberia'],
#  ['Standard Lager', 'New Zealand White', 'American Rose', 'American Red'],
#  ['American Red'],
#  ['South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australia White',
#   'American White',
#   'American Red'],
#  ['Ready To Drink'],
#  ['World Beer',
#   'Speciality Beer',
#   'Sparkling',
#   'South America',
#   'Premium Lager',
#   'New Zealand Red',
#   'Nablab',
#   'Malt Whisky',
#   'Iberia',
#   'Gin',
#   'French White 2',
#   'French Red South',
#   'Ethnic',
#   'Brandy/Cognac',
#   'America White'],
#  ['Vodka', 'Sparkling', 'Everyday Cider', 'Cocktails/Liqueurs'],
#  ['Premium Lager', 'Everyday Cider'],
#  ['Standard Lager', 'Premium Lager'],
#  ['Iberia'],
#  ['Sparkling', 'Own Label', 'Nablab'],
#  ['Stout',
#   'South America',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Premium Lager',
#   'New Zealand White',
#   'Gin',
#   'Everyday Cider',
#   'Champagne',
#   'Australian Red',
#   'Australia White',
#   'American Red',
#   'America White'],
#  ['Premium Lager'],
#  ['Sherry Spanish', 'Rum'],
#  ['World Beer', 'Premium Cider', 'French White 2', 'Australian Red'],
#  ['White Boxes',
#   'South African White',
#   'South Africa White',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Italian White',
#   'Iberia',
#   'Gin',
#   'Australian Red'],
#  ['Small Sizes White', 'Premium Canned Ale'],
#  ['Italian White', 'Iberia White'],
#  ['New Zealand White', 'French Red South'],
#  ['World Beer',
#   'New Zealand White',
#   'Italian White',
#   'Italian Red',
#   'Everyday Cider',
#   'Cocktails/Liqueurs'],
#  ['Bottled Ale'],
#  ['Cocktails/Liqueurs'],
#  ['White Rum',
#   'South African White',
#   'South Africa Red',
#   'Italy White',
#   'Italian Red'],
#  ['White Boxes', 'Red Wine Bxes & 25Cl', 'Gin', 'Everyday Cider'],
#  ['Sparkling',
#   'South America',
#   'South African White',
#   'Small Sizes Red',
#   'Premium Lager',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'Gin',
#   'French White',
#   'French Red South',
#   'French Red 2',
#   'French Red',
#   'Everyday Cider',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Rose',
#   'American Red',
#   'America White'],
#  ['Sparkling'],
#  ['Iberia White', 'Iberia'],
#  ['World Beer',
#   'Stout',
#   'Standard Lager',
#   'Italian Red',
#   'Champagne',
#   'Australian Red'],
#  ['Other Red', 'Australian Red'],
#  ['Speciality Beer', 'Premium Cider', 'No/Low Alc Cider', 'American White'],
#  ['Sparkling',
#   'South Africa White',
#   'Rum',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'French White South',
#   'Australian White',
#   'Australian Red'],
#  ['Sparkling', 'Premium Lager', 'Nablab', 'Made Wine British', 'Champagne'],
#  ['Premium Lager', 'Australian White', 'Australian Red'],
#  ['Sparkling', 'Australian Red'],
#  ['Over-Ice Cider'],
#  ['World Beer',
#   'Spirits Mixers',
#   'South America White',
#   'Sherry Spanish',
#   'Bottled Ale'],
#  ['Basics'],
#  ['World Beer', 'Premium Lager', 'Nablab'],
#  ['South America White', 'New Zealand White'],
#  ['Vodka',
#   'Sparkling',
#   'Over-Ice Cider',
#   'Italy White',
#   'Cocktails/Liqueurs',
#   'American Red'],
#  ['South America White',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French Red South',
#   'French Red 2'],
#  ['Sparkling',
#   'South America',
#   'South Africa Red',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian Red',
#   'Bitter',
#   'American White'],
#  ['Italy White', 'Cocktails/Liqueurs'],
#  ['Premium Lager', 'Gin', 'Cocktails/Liqueurs', 'Bottled Ale'],
#  ['White Rum',
#   'Standard Lager',
#   'Sparkling',
#   'Premium Lager',
#   'Premium Cider',
#   'New Zealand White',
#   'Italian Red',
#   'French White 2',
#   'Brnd Alchol Carbntes',
#   'Australian Red'],
#  ['White Boxes', 'Stout', 'Premium Lager', 'French White 2'],
#  ['Whisky',
#   'Stout',
#   'Standard Lager',
#   'Sparkling',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Over-Ice Cider',
#   'Italian White',
#   'Iberia White',
#   'German',
#   'Fruit Cider',
#   'Brandy/Cognac',
#   'Bitter'],
#  ['Over-Ice Cider'],
#  ['Sherry Spanish'],
#  ['Premium Lager', 'Cocktails/Liqueurs', 'Champagne', 'American White'],
#  ['South Africa Red', 'Italian Red'],
#  ['Small Sizes Wht Othr'],
#  ['Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South African White',
#   'South Africa White',
#   'Premium Lager',
#   'Premium Cider',
#   'New Zealand White',
#   'Malt Whisky',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Fruit Cider',
#   'French White Loire',
#   'French White 2',
#   'Australian White',
#   'Australia White',
#   'America White'],
#  ['World Beer', 'South Africa White', 'Premium Lager'],
#  ['Sparkling', 'Premium Canned Ale', 'Italy White', 'Australian Red'],
#  ['World Beer',
#   'South America White',
#   'South America',
#   'Australian White',
#   'Australian Red',
#   'American Red'],
#  ['Vermouths/Aperitifs', 'South America', 'Premium Lager', 'French White'],
#  ['Standard Lager'],
#  ['White Boxes', 'Speciality Beer', 'Premium Lager', 'Australian White'],
#  ['Iberia White', 'French White', 'Everyday Cider', 'America White'],
#  ['Iberia White', 'Gin', 'French Red 2'],
#  ['South America', 'Premium Lager', 'Port'],
#  ['South Africa Red',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'American White'],
#  ['World Beer', 'Whisky', 'New Zealand White', 'Brandy/Cognac', 'Bottled Ale'],
#  ['Rum', 'Italian Red', 'Australian Red'],
#  ['Small Sizes White', 'Small Sizes Red', 'Over-Ice Cider'],
#  ['Standard Lager', 'Premium Lager', 'Italy White', 'Iberia White'],
#  ['Premium Lager', 'Australian White'],
#  ['World Beer',
#   'Stout',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'German',
#   'Bottled Ale',
#   'American White',
#   'American Red',
#   'America White'],
#  ['World Beer',
#   'Whisky',
#   'Vodka',
#   'Speciality Beer',
#   'Sparkling',
#   'South America',
#   'Premium Lager',
#   'New Zealand Red',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Iberia',
#   'Gin',
#   'French White 2',
#   'French Red 2',
#   'French Red',
#   'Cocktails/Liqueurs',
#   'Australian Red',
#   'American White'],
#  ['World Beer', 'Sparkling', 'Iberia'],
#  ['Italy White', 'Australian White', 'Australian Red'],
#  ['Iberia'],
#  ['Premium Lager'],
#  ['World Beer',
#   'Standard Lager',
#   'South African White',
#   'Premium Lager',
#   'Brnd Alchol Carbntes'],
#  ['Iberia'],
#  ['Sparkling', 'Over-Ice Cider'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Brandy/Cognac',
#   'Australian White',
#   'Australia White'],
#  ['World Beer', 'Standard Lager', 'Cooking Wine', 'Bottled Ale'],
#  ['Sparkling', 'Champagne', 'American White', 'American Red'],
#  ['Premium Lager', 'Port'],
#  ['Sparkling', 'French Red 2', 'Australian White'],
#  ['World Beer',
#   'Spirits Mixers',
#   'South Africa White',
#   'Italian White',
#   'American White'],
#  ['Vodka'],
#  ['Sparkling',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'French Red 2',
#   'French Red'],
#  ['Iberia', 'Australian Red'],
#  ['White Rum', 'Whisky', 'Vodka', 'Rum', 'Malt Whisky', 'Cocktails/Liqueurs'],
#  ['South Africa Red', 'American Red', 'America White'],
#  ['Vodka', 'Cocktails/Liqueurs'],
#  ['Sparkling',
#   'Sherry Spanish',
#   'Premium Lager',
#   'New Zealand White',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red'],
#  ['Fruit Cider'],
#  ['World Beer',
#   'Sparkling',
#   'Premium Lager',
#   'Italian White',
#   'Italian Red',
#   'Australian Red'],
#  ['Nablab'],
#  ['Standard Lager',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'Premium Lager',
#   'Italy White',
#   'French Red 2',
#   'Bitter',
#   'Australian Red'],
#  ['Std Canned Ale',
#   'South Africa White',
#   'Premium Canned Ale',
#   'Over-Ice Cider',
#   'Nablab',
#   'Italy White',
#   'Iberia',
#   'French Red South',
#   'Champagne',
#   'Bottled Ale',
#   'Bitter',
#   'Australian White',
#   'Australian Red',
#   'America White'],
#  ['Spirits & Fortified', 'Made Wine British', 'Australian White'],
#  ['Port'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French White South',
#   'French Red South',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red'],
#  ['White Boxes', 'Premium Lager', 'Italy White', 'Australian Red'],
#  ['World Beer', 'Standard Lager', 'Speciality Beer'],
#  ['Italy White', 'Italian Red'],
#  ['White Boxes',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Iberia',
#   'Fruit Cider',
#   'French White 2',
#   'French White',
#   'Everyday Cider',
#   'Champagne',
#   'Brnd Alchol Carbntes',
#   'Australian White',
#   'America White'],
#  ['Premium Lager', 'Bottled Ale'],
#  ['Spirits Mixers',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'French White 2',
#   'America White'],
#  ['American White', 'America White'],
#  ['South Africa Red',
#   'Other Red',
#   'Kosher Red',
#   'Australian White',
#   'American Rose',
#   'America White'],
#  ['Premium Lager', 'Iberia', 'Australian White', 'American White'],
#  ['Fruit Cider'],
#  ['New Zealand White', 'New Zealand Red'],
#  ['South America', 'Premium Lager', 'America White'],
#  ['World Beer',
#   'Spirits Mixers',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Gin',
#   'Australian White'],
#  ['Sparkling', 'America White'],
#  ['Stout'],
#  ['Sparkling', 'Premium Lager', 'Italy White', 'Beer/Lager Gifts'],
#  ['World Beer',
#   'Sparkling',
#   'Premium Lager',
#   'French White South',
#   'French White',
#   'Australian Red',
#   'American White',
#   'American Rose',
#   'America White'],
#  ['World Beer', 'Over-Ice Cider', 'New Zealand White', 'New Zealand Red'],
#  ['Other Red', 'Cocktails/Liqueurs'],
#  ['World Beer',
#   'Sparkling',
#   'South America',
#   'South Africa Red',
#   'Australian Red'],
#  ['South America',
#   'Premium Lager',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'French White Rhone',
#   'French White 2',
#   'French Red',
#   'Australian Red'],
#  ['Bottled Ale'],
#  ['Sparkling', 'Premium Cider'],
#  ['Standard Lager',
#   'Sparkling',
#   'South African White',
#   'South Africa Red',
#   'Italy White',
#   'Bottled Ale'],
#  ['South America',
#   'South African White',
#   'South Africa Red',
#   'Italian Red',
#   'Australian Red',
#   'American Red'],
#  ['Speciality Beer',
#   'Red Wine Bxes & 25Cl',
#   'Iberia',
#   'Bottled Ale',
#   'Australian Red'],
#  ['White Boxes',
#   'Whisky',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Gin'],
#  ['Premium Lager', 'Iberia', 'Beer/Lager Gifts'],
#  ['World Beer', 'Premium Lager', 'Italy White', 'French White South'],
#  ['World Beer',
#   'Standard Lager',
#   'Sparkling',
#   'Premium Canned Ale',
#   'Champagne'],
#  ['Italy White', 'Australian White'],
#  ['Whisky', 'Vodka', 'Malt Whisky', 'Bottled Ale', 'Bitter'],
#  ['Premium Lager'],
#  ['Standard Lager',
#   'Spirits Mixers',
#   'Premium Lager',
#   'Italy White',
#   'Cooking Wine',
#   'Champagne',
#   'Bitter'],
#  ['Premium Lager', 'Italy White', 'Australia White'],
#  ['Everyday Cider', 'Australia White'],
#  ['Gin'],
#  ['Spirits Mixers',
#   'South America White',
#   'Small Sizes Red',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Premium Cider',
#   'Italy White',
#   'French Red 2',
#   'French Red',
#   'Fine Wines',
# ...
#   'Iberia',
#   'Gin',
#   'French White Loire',
#   'French White 2',
#   'Bottled Ale',
#   'Bitter'],
#  ['World Beer',
#   'Stout',
#   'Sparkling',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Rum',
#   'Premium Lager',
#   'Port',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Gin',
#   'French Red 2',
#   'Australia White'],
#  ['South America White',
#   'South America',
#   'Sherry Spanish',
#   'Other Red',
#   'Made Wine British',
#   'Italian White',
#   'Italian Red',
#   'Gin',
#   'French Red 2',
#   'Brandy/Cognac',
#   'Australian White'],
#  ['Whisky',
#   'Speciality Beer',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'Made Wine British',
#   'Bottled Ale'],
#  ['Vodka', 'Gin', 'Cooking Wine'],
#  ['World Beer',
#   'Speciality Beer',
#   'South America',
#   'New Zealand White',
#   'Italy White',
#   'French White 2',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Australian Red',
#   'Australia White'],
#  ['South African White', 'Other Red', 'Australian Red'],
#  ['New Zealand White',
#   'Italy White',
#   'French White 2',
#   'Cooking Wine',
#   'Champagne',
#   'Bottled Ale',
#   'Australian White'],
#  ['Nablab'],
#  ['World Beer',
#   'White Boxes',
#   'South Africa Red',
#   'Red Wine Bxes & 25Cl',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Iberia',
#   'Australian White',
#   'American Red',
#   'America White'],
#  ['Over-Ice Cider', 'Everyday Cider'],
#  ['Whisky', 'Sherry Spanish', 'Bottled Ale'],
#  ['World Beer',
#   'Whisky',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Malt Whisky',
#   'Cocktails/Liqueurs',
#   'Brandy/Cognac'],
#  ['Italy White'],
#  ['Sparkling', 'Italian Red'],
#  ['World Beer',
#   'White Boxes',
#   'Standard Lager',
#   'Sparkling',
#   'Italy White',
#   'Italian White',
#   'Champagne',
#   'Bitter',
#   'American White',
#   'America White'],
#  ['White Rum', 'Sherry Spanish', 'Rum', 'Premium Lager', 'Iberia', 'Gin'],
#  ['Stout',
#   'Standard Lager',
#   'Spirits Mixers',
#   'Speciality Beer',
#   'South Africa White',
#   'Rum',
#   'Italy White',
#   'Everyday Cider',
#   'Bitter',
#   'Australian White',
#   'Australian Red'],
#  ['Standard Lager',
#   'Sparkling',
#   'South America White',
#   'South Africa White',
#   'South Africa Red',
#   'Own Label',
#   'Miscellaneous',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'Fruit Cider',
#   'French White 2',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['South Africa White',
#   'French White 2',
#   'French Red 2',
#   'French Red',
#   'Bottled Ale'],
#  ['Premium Lager', 'French White 2', 'French Red 2'],
#  ['Standard Lager', 'Nablab', 'Italian White'],
#  ['South America White', 'Italy White', 'Italian White'],
#  ['White Boxes',
#   'Vodka',
#   'Red Wine Bxes & 25Cl',
#   'Premium Cider',
#   'Port',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian White',
#   'Gin',
#   'Fruit Cider',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Australian Red'],
#  ['World Beer', 'French Red South', 'Australian Red'],
#  ['South America White',
#   'South America',
#   'Small Sizes White',
#   'Small Sizes Red',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'French Red 2',
#   'British Fortified'],
#  ['South African White',
#   'South Africa Red',
#   'New Zealand White',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian White',
#   'Australia White'],
#  ['New Zealand White'],
#  ['World Beer', 'Gin'],
#  ['Cocktails/Liqueurs'],
#  ['World Beer'],
#  ['Nablab'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'Italy White',
#   'Italian Red'],
#  ['Speciality Beer',
#   'South Africa White',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Port',
#   'Bitter',
#   'American White',
#   'America White'],
#  ['Speciality Beer',
#   'Sparkling',
#   'South America',
#   'South Africa Red',
#   'Premium Canned Ale',
#   'Port',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'Gin',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'American White'],
#  ['Australian Red'],
#  ['Iberia', 'French White 2', 'French Red 2', 'Bottled Ale'],
#  ['Over-Ice Cider'],
#  ['Stout',
#   'New Zealand White',
#   'German',
#   'French Red South',
#   'French Red 2',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['Sparkling',
#   'South America White',
#   'Premium Lager',
#   'French White 2',
#   'Everyday Cider',
#   'American White',
#   'America White'],
#  ['White Boxes',
#   'Speciality Beer',
#   'Sparkling',
#   'Red Wine Bxes & 25Cl',
#   'Ireland Products'],
#  ['World Beer',
#   'Vodka',
#   'Spirits & Fortified',
#   'Sparkling',
#   'South America',
#   'South Africa White',
#   'Premium Lager',
#   'Premium Cider',
#   'Port',
#   'New Zealand White',
#   'Fine Wines',
#   'Everyday Cider',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian Red'],
#  ['World Beer',
#   'Whisky',
#   'Sparkling',
#   'South America',
#   'Premium Lager',
#   'Premium Canned Ale',
#   'Over-Ice Cider',
#   'Bottled Ale',
#   'Bitter',
#   'Australian White',
#   'Australian Red',
#   'American Red',
#   'America White'],
#  ['World Beer',
#   'Nablab',
#   'Malt Whisky',
#   'Italy White',
#   'Italian Red',
#   'Brandy/Cognac'],
#  ['Vodka',
#   'Speciality Beer',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Italian Red',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American Red'],
#  ['World Beer', 'White Rum', 'Sparkling', 'Bottled Ale', 'Australian White'],
#  ['Sparkling'],
#  ['Australian Red'],
#  ['South Africa Red', 'Premium Lager', 'American Red'],
#  ['World Beer',
#   'Spirits & Fortified',
#   'South Africa Red',
#   'Premium Lager',
#   'French Red 2',
#   'Australia White',
#   'American White',
#   'American Red',
#   'America White'],
#  ['Standard Lager',
#   'Speciality Beer',
#   'South Africa Red',
#   'Small Sizes Wht Othr',
#   'Premium Canned Ale',
#   'America White'],
#  ['World Beer', 'Over-Ice Cider', 'Fruit Cider'],
#  ['World Beer',
#   'Vodka',
#   'Vermouths/Aperitifs',
#   'Stout',
#   'Standard Lager',
#   'Sparkling',
#   'Premium Lager',
#   'Iberia White',
#   'Everyday Cider',
#   'Brnd Alchol Carbntes',
#   'Basics'],
#  ['White Boxes',
#   'Sparkling',
#   'South African White',
#   'Premium Lager',
#   'Italy White',
#   'Italian White',
#   'Gin',
#   'Everyday Cider',
#   'Bottled Ale'],
#  ['South Africa Red', 'Other Red', 'Italian Red', 'Iberia'],
#  ['World Beer', 'Sparkling', 'Premium Lager', 'Premium Cider', 'American Red'],
#  ['Premium Lager'],
#  ['Small Sizes White', 'Over-Ice Cider', 'Champagne', 'Bottled Ale'],
#  ['Australian White'],
#  ['South America White',
#   'Rum',
#   'Premium Cider',
#   'French Red 2',
#   'Cooking Wine',
#   'Cocktails/Liqueurs',
#   'Australian Red'],
#  ['World Beer',
#   'White Rum',
#   'Whisky',
#   'Vodka',
#   'Speciality Beer',
#   'Sparkling',
#   'South Africa White',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Premium Cider',
#   'Over-Ice Cider',
#   'Malt Whisky',
#   'Italy White',
#   'Gin',
#   'French White 2',
#   'French Red 2',
#   'Champagne',
#   'Brandy/Cognac',
#   'Bottled Ale'],
#  ['White Boxes',
#   'Whisky',
#   'Vodka',
#   'Vermouths/Aperitifs',
#   'Red Wine Bxes & 25Cl',
#   'Premium Lager',
#   'Port',
#   'Malt Whisky',
#   'Italy White',
#   'Iberia',
#   'Gin',
#   'Fine Wines',
#   'Everyday Cider',
#   'Bottled Ale'],
#  ['South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French Red 2',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'American Rose',
#   'American Red'],
#  ['Australian Red'],
#  ['Vodka'],
#  ['South Africa Red', 'Italian Red'],
#  ['South America White',
#   'South African White',
#   'South Africa White',
#   'Premium Lager',
#   'Italy White',
#   'Australian White',
#   'America White'],
#  ['World Beer',
#   'Whisky',
#   'Standard Lager',
#   'South America White',
#   'South Africa Red',
#   'Premium Lager',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French White',
#   'French Red 2',
#   'French Red',
#   'Champagne',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red'],
#  ['South America',
#   'South Africa Red',
#   'Premium Lager',
#   'Italy White',
#   'Iberia',
#   'French White 2',
#   'French Red South',
#   'Champagne',
#   'Bottled Ale',
#   'Australian Red'],
#  ['Standard Lager',
#   'Port',
#   'Italy White',
#   'Italian White',
#   'Iberia',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Champagne'],
#  ['Whisky', 'Vodka', 'Spirits Mixers', 'South America White'],
#  ['Whisky',
#   'Standard Lager',
#   'Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'Premium Lager',
#   'Premium Cider',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'Gin',
#   'Fruit Cider',
#   'Everyday Cider',
#   'Bitter',
#   'Australian White',
#   'Australian Rose',
#   'American White',
#   'American Rose',
#   'American Red',
#   'America White'],
#  ['Vermouths/Aperitifs',
#   'South America White',
#   'South Africa White',
#   'New Zealand White',
#   'Gin',
#   'French White South',
#   'French Red South',
#   'Australian Red'],
#  ['Premium Lager', 'Italian Red', 'French White 2'],
#  ['World Beer', 'Vodka', 'Over-Ice Cider', 'French White Loire'],
#  ['Speciality Beer',
#   'Sparkling',
#   'Premium Lager',
#   'New Zealand White',
#   'Champagne',
#   'Bottled Ale'],
#  ['Iberia'],
#  ['World Beer', 'Premium Lager', 'French Red 2'],
#  ['World Beer',
#   'Vodka',
#   'Spirits Mixers',
#   'Sparkling',
#   'Premium Lager',
#   'New Zealand White',
#   'Nablab',
#   'Iberia',
#   'French Red South',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'America White'],
#  ['Iberia White'],
#  ['World Beer', 'Port', 'New Zealand White', 'Bottled Ale', 'Australian Red'],
#  ['Stout'],
#  ['White Boxes',
#   'Stout',
#   'South Africa Red',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'Australian Red'],
#  ['World Beer'],
#  ['Nablab'],
#  ['World Beer', 'Vodka', 'Cocktails/Liqueurs'],
#  ['World Beer', 'Red Wine Bxes & 25Cl', 'Premium Lager', 'French Red 2'],
#  ['Fine Wines'],
#  ['White Boxes',
#   'Standard Lager',
#   'Over-Ice Cider',
#   'Italy White',
#   'German',
#   'Fruit Cider'],
#  ['Italy White',
#   'Italian White',
#   'Italian Red',
#   'Australian Red',
#   'Australia White'],
#  ['Sparkling', 'Small Sizes White', 'Italy White', 'America White'],
#  ['Sparkling',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Italy White',
#   'Australian White',
#   'Australian Red',
#   'Australia White',
#   'American White',
#   'America White'],
#  ['Vodka'],
#  ['South America White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Iberia White',
#   'Bottled Ale',
#   'American White',
#   'America White'],
#  ['German'],
#  ['Premium Lager'],
#  ['Vodka', 'Premium Cider', 'Bitter'],
#  ['World Beer', 'White Rum'],
#  ['South Africa Red', 'Iberia', 'Bottled Ale'],
#  ['World Beer',
#   'South Africa Red',
#   'Premium Canned Ale',
#   'Over-Ice Cider',
#   'Bottled Ale',
#   'Australian Sparkling',
#   'Australian Red'],
#  ['White Rum', 'Spirits & Fortified', 'Australian White'],
#  ['Champagne'],
#  ['Port', 'Italy White', 'American Red', 'America White'],
#  ['Premium Lager',
#   'Premium Canned Ale',
#   'Port',
#   'French Red 2',
#   'French Red',
#   'Bottled Ale',
#   'Australian Red'],
#  ['Premium Cider'],
#  ['Premium Lager'],
#  ['Premium Lager', 'French Red 2', 'Everyday Cider', 'Cocktails/Liqueurs'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa Red',
#   'Red Wine Bxes & 25Cl',
#   'New Zealand White',
#   'Italian Red',
#   'French White South',
#   'Australian Red',
#   'American Red'],
#  ['Italian White', 'Champagne', 'American Red'],
#  ['World Beer',
#   'White Rum',
#   'Standard Lager',
#   'Sparkling',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Iberia',
#   'French White 2',
#   'French Red 2',
#   'French Red',
#   'Brnd Alchol Carbntes',
#   'Bitter',
#   'Australian Red',
#   'Australia White'],
#  ['Sparkling', 'New Zealand White'],
#  ['Rum'],
#  ['Premium Canned Ale', 'Over-Ice Cider', 'Cocktails/Liqueurs', 'Bottled Ale'],
#  ['Vermouths/Aperitifs',
#   'South America',
#   'South Africa Red',
#   'Sherry Spanish',
#   'Port',
#   'Cocktails/Liqueurs',
#   'Australian Red'],
#  ['Standard Lager',
#   'Spirits Mixers',
#   'Speciality Beer',
#   'Sparkling',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Port',
#   'Over-Ice Cider',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White 2',
#   'French Red 2',
#   'Champagne',
#   'Bitter',
#   'Australian White',
#   'Australian Rose',
#   'Australian Red',
#   'Australia White',
#   'American Red',
#   'America White'],
#  ['South Africa Red', 'Cocktails/Liqueurs', 'Australian Red'],
#  ['Australian White'],
#  ['Standard Lager',
#   'Spirits Mixers',
#   'Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'Premium Lager',
#   'Port',
#   'Other Red',
#   'New Zealand White',
#   'Italy White',
#   'Italian Red',
#   'Iberia',
#   'French White South',
#   'French Red South',
#   'French Red 2',
#   'Champagne',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ['World Beer',
#   'South African White',
#   'Premium Lager',
#   'Over-Ice Cider',
#   'Italian Red',
#   'Iberia',
#   'Australian White',
#   'American White',
#   'America White'],
#  ['American White'],
#  ['Spirits Mixers'],
#  ['Wine Gifts',
#   'Vermouths/Aperitifs',
#   'Sparkling',
#   'South America White',
#   'South African White',
#   'South Africa Red',
#   'Premium Cider',
#   'Premium Canned Ale',
#   'Other Red',
#   'Italy White',
#   'Italian White',
#   'Iberia White',
#   'Iberia',
#   'French White',
#   'French Red 2',
#   'Cocktails/Liqueurs',
#   'Bottled Ale',
#   'Beer/Lager Gifts',
#   'Australian Red',
#   'American Rose'],
#  ['World Beer', 'Italy White'],
#  ['Sparkling', 'French White', 'Cocktails/Liqueurs', 'Brnd Alchol Carbntes'],
#  ['Italian White',
#   'Italian Red',
#   'Iberia White',
#   'French White South',
#   'French White 2'],
#  ['Sherry Spanish'],
#  ['World Beer', 'Premium Cider'],
#  ['Whisky',
#   'South Africa White',
#   'Port',
#   'Madeira & Marsala',
#   'Italy White',
#   'Iberia',
#   'Everyday Cider',
#   'Champagne',
#   'Australian Red'],
#  ['World Beer',
#   'Standard Lager',
#   'Sparkling',
#   'Sherry Spanish',
#   'Made Wine British',
#   'Bitter'],
#  ['Bottled Ale', 'Bitter', 'American White'],
#  ['Small Sizes White'],
#  ['Premium Lager',
#   'Own Label',
#   'Over-Ice Cider',
#   'French Red South',
#   'French Red 2',
#   'Australian Red'],
#  ['World Beer', 'Speciality Beer'],
#  ['White Boxes', 'Premium Lager', 'Italian White', 'Cocktails/Liqueurs'],
#  ['Sherry Spanish', 'New Zealand White'],
#  ['Vodka',
#   'Standard Lager',
#   'Spirits Mixers',
#   'Sparkling',
#   'Sherry Spanish',
#   'Premium Lager',
#   'Own Label',
#   'Over-Ice Cider',
#   'Low Alcohol A.C',
#   'Italy White',
#   'Gin',
#   'Cocktails/Liqueurs',
#   'Champagne',
#   'Australian Red',
#   'American White',
#   'America White'],
#  ['Premium Lager', 'Italian Red', 'Iberia'],
#  ['Sparkling',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'New Zealand White',
#   'New Zealand Red',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Iberia White',
#   'Iberia',
#   'French White South',
#   'French White 2',
#   'French Red South',
#   'French Red 2',
#   'Fine Wines',
#   'Australian Red',
#   'Australia White',
#   'American Red',
#   'America White'],
#  ['World Beer',
#   'White Boxes',
#   'Stout',
#   'Standard Lager',
#   'South America White',
#   'South America',
#   'South African White',
#   'South Africa White',
#   'South Africa Red',
#   'Premium Lager',
#   'New Zealand White',
#   'Italian White',
#   'Italian Red',
#   'Iberia',
#   'Everyday Cider',
#   'Bottled Ale',
#   'Australian White',
#   'Australian Red',
#   'American Red'],
#  ['World Beer',
#   'Vodka',
#   'South America White',
#   'South America',
#   'South Africa White',
#   'South Africa Red',
#   'Over-Ice Cider',
#   'New Zealand White',
#   'Italy White',
#   'Italian White',
#   'Italian Red',
#   'Australian White',
#   'Australian Red',
#   'Australia White'],
#  ...]

# %%
len(transactions_list)
# there are 3567 lists in our master list
# Out:
# 3567

# %%
# Applying Apriori Alogirthm

# we now specifiy the association rules we want 

apriori_rules = apriori(transactions_list,
                       min_support = 0.003,
                       min_confidence = 0.2,
                       min_lift = 3,
                        min_length = 2,
                        max_length = 2)

# support = is the percentage of all transactions that contain both item A & item B
# im using 0.003 because it came out quite well

# confidence = of all the transactions that included item A , how much proportion of those included item B

# lift = is the factor where confidence exceeds the expected confidence.
# In other words, how likely the two items is purchased together compared to what would be expected based
# on their individual purchase rate

# if you run without min & max length it will essentially compute combinations of all lengths and this can
# take very very long time & does'nt actually give us what we really want here
# here we want individual item to item relationship so we specify min & max length of 2

# %%
# now we want to convert into list as it is currently in form of "Generator"
# A generator is a special type of function in python specifically used for iterating through
# data

apriori_rules = list(apriori_rules)

# %%
len(apriori_rules)
# so essentially we have 132 rules that met the criteria we set above when we ran the algorithm
# Out:
# 132

# %%
apriori_rules[0]
# we see the data is in form of funny format xD
# Out:
# RelationRecord(items=frozenset({'America White', 'American Rose'}), support=0.020745724698626296, ordered_statistics=[OrderedStatistic(items_base=frozenset({'American Rose'}), items_add=frozenset({'America White'}), confidence=0.5323741007194245, lift=3.997849299507762)])

# %%
# Convert output to DataFrame

product1=[list(rule[2][0][0])[0] for rule in apriori_rules]
product2=[list(rule[2][0][1])[0] for rule in apriori_rules]
support = [rule[1] for rule in apriori_rules]
confidence = [rule[2][0][2] for rule in apriori_rules]
lift = [rule[2][0][3] for rule in apriori_rules]

# %%
apriori_rules_df = pd.DataFrame({"Product1":product1,
                                 "Product2":product2,
                                 "support": support,
                                "confidence": confidence,
                                "lift" : lift})

# %%
apriori_rules_df
# Out:
#                 Product1             Product2   support  confidence      lift
# 0          American Rose        America White  0.020746    0.532374  3.997849
# 1          America White       American White  0.054387    0.408421  3.597131
# 2        Australian Rose        America White  0.005046    0.486486  3.653257
# 3        Low Alcohol A.C        America White  0.003364    0.461538  3.465911
# 4          American Rose         American Red  0.015699    0.402878  3.574788
# ..                   ...                  ...       ...         ...       ...
# 127   South Africa White  South America White  0.039529    0.413490  3.997067
# 128  South African White  South America White  0.030278    0.398524  3.852399
# 129           Wine Gifts  Spirits & Fortified  0.005887    0.411765  9.537433
# 130            White Rum                Vodka  0.025231    0.486486  3.060489
# 131           Wine Gifts            White Rum  0.003084    0.215686  4.158665
#
# [132 rows x 5 columns]

# %% [markdown]
# In the DataFrame we have the two products in the pair, and then the three key metrics; Support, Confidence, and Lift.

# %%
apriori_rules_df.sort_values(by='lift',ascending=False,inplace=True)

# %%
apriori_rules_df.head(20)
# Out:
#                  Product1             Product2   support  confidence  \
# 35             Wine Gifts     Beer/Lager Gifts  0.004486    0.313725
# 34       Beer/Lager Gifts  Spirits & Fortified  0.013176    0.427273
# 129            Wine Gifts  Spirits & Fortified  0.005887    0.411765
# 118  Red Wine Bxes & 25Cl          White Boxes  0.015419    0.474138
# 52     French White Rhone           French Red  0.003364    0.480000
# 123  Small Sizeswhite Oth    Small Sizes White  0.005327    0.558824
# 119       Small Sizes Red    Small Sizes White  0.024951    0.486339
# 79     French White Loire   French White South  0.004205    0.348837
# 73     French White Rhone       French White 2  0.005327    0.760000
# 120  Small Sizeswhite Oth      Small Sizes Red  0.003084    0.323529
# 122  Small Sizes Wht Othr    Small Sizes White  0.003364    0.413793
# 109       New Zealand Red          Malt Whisky  0.005327    0.271429
# 84     French White Rhone         Iberia White  0.003084    0.440000
# 72     French White Loire       French White 2  0.007289    0.604651
# 51     French White Loire           French Red  0.003364    0.279070
# 80     French White Loire    New Zealand White  0.008410    0.697674
# 107       Lambrusco Rosso        Italian White  0.003084    0.785714
# 56     French White Rhone         French Red 2  0.005046    0.720000
# 31                Barware          Malt Whisky  0.004486    0.225352
# 27        Australian Rose  South African White  0.003645    0.351351
#
#           lift
# 35   10.173262
# 34    9.896635
# 129   9.537433
# 118   9.343923
# 52    8.691168
# 123   8.340266
# 119   7.258454
# 79    6.762513
# 73    6.660737
# 120   6.306172
# 122   6.175732
# 109   5.628987
# 84    5.468571
# 72    5.299240
# 51    5.053004
# 80    5.007253
# 107   4.718254
# 56    4.703736
# 31    4.673436
# 27    4.624614

# %% [markdown]
# So here we can see the product1 "Wine Gifts", product2 "Beer/Lager Gifts" have strongest relationship between each
# other. perhaps, we can place all "alcohol gifts" together rather than individual product areas. its just an idea
# we need to discuss further with ABC Grocery but it does seem like something is there.
#
# There appears some french wines bought together as well which is interesting and also there is words such as "Small" we don't know what it is, but it might be interesting when we show this to guys at ABC Grocery
#
# these sorts of insights are "GOLD DUST" to the category team at grocery store as it gives them data driven
# insights to how they should construct their area of store

# %%
# Search Rules

apriori_rules_df[apriori_rules_df['Product1'].str.contains("New Zealand")]
# Out:
#               Product1             Product2   support  confidence      lift
# 109    New Zealand Red          Malt Whisky  0.005327    0.271429  5.628987
# 103    New Zealand Red         Iberia White  0.007289    0.371429  4.616327
# 111    New Zealand Red    New Zealand White  0.012616    0.642857  4.613826
# 90     New Zealand Red   French White South  0.004486    0.228571  4.431056
# 75     New Zealand Red       French White 2  0.009532    0.485714  4.256862
# 53     New Zealand Red           French Red  0.004205    0.214286  3.879985
# 63     New Zealand Red     French Red South  0.006448    0.328571  3.868034
# 113    New Zealand Red        South America  0.010934    0.557143  3.799863
# 112    New Zealand Red            Other Red  0.004486    0.228571  3.591693
# 102    New Zealand Red               Iberia  0.012055    0.614286  3.528433
# 44     New Zealand Red            Champagne  0.008691    0.442857  3.526052
# 116  New Zealand White  South America White  0.049341    0.354125  3.423206
# 58     New Zealand Red         French Red 2  0.010093    0.514286  3.359812
# 114    New Zealand Red  South America White  0.006728    0.342857  3.314286
# 17     New Zealand Red      Australia White  0.007289    0.371429  3.215742
# 99     New Zealand Red                  Gin  0.007289    0.371429  3.095527
# 6      New Zealand Red         American Red  0.006728    0.342857  3.042217
# 106    New Zealand Red          Italian Red  0.010373    0.528571  3.036094
# 115  New Zealand White   South Africa White  0.040370    0.289738  3.030783

# %% [markdown]
# There appears to be some relationship between New Zealand wines and other New Zealand wines, but what is also interesting is that New Zealand wines seem to be more associated with French & South American wines than they are with Australian Wines.
#
# New Zealand & Australia are often grouped together, but in terms of wine this wouldn’t make sense - perhaps because of the difference climates the wines are very different and thus it wouldn’t make sense to group wines by geographical proximity, but by preference instead. This is only a hypothesis for now - we will need to take this back to the client and get their category experts to help us interpret it!
